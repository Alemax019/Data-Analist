# %%
# importamos la librerias necesarias
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
coursera = pd.read_csv('./Dataset_PI03_Data_Analyst/coursera_all.csv')
edx = pd.read_csv('./Dataset_PI03_Data_Analyst/edx_all.csv')
udemy = pd.read_csv('./Dataset_PI03_Data_Analyst/udemy_all.csv')
stopwords = set(STOPWORDS)

# %%
udemy.head()
# Out:
#    Unnamed: 0                                       course_title  price  \
# 0           0                 Ultimate Investment Banking Course    200
# 1           1  Complete GST Course & Certification - Grow You...     75
# 2           2  Financial Modeling for Business Analysts and C...     45
# 3           3  Beginner to Pro - Financial Analysis in Excel ...     95
# 4           4       How To Maximize Your Profits Trading Options    200
#
#   institution plataform
# 0       udemy     udemy
# 1       udemy     udemy
# 2       udemy     udemy
# 3       udemy     udemy
# 4       udemy     udemy

# %%
text = coursera.name[4]
wordej = WordCloud().generate(text)

# %%
plt.imshow(wordej, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordej = WordCloud(max_font_size=50, max_words=100,background_color='white').generate(text)
plt.figure()
plt.imshow(wordej, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordej.to_file('./Dataset_PI03_Data_Analyst/first_review.png')

# %%
text2 = ' '.join(reviews for reviews in coursera['name'])

# %%
lista = ['I','It','The','This','one','would','2','really','much','even','way','courses','de','que','There','get','like','first',
         'lot','They','If','They','course','many','la','de','y']
for i in lista:
    stopwords.update(i)

# %%
import pandas as pd
from pandas.plotting import register_matplotlib_converters
import matplotlib.dates as mdates

mdates._reset_epoch_test_example()
mdates.set_epoch('0000-12-31T00:00:00')  # old epoch (pre MPL 3.3)
register_matplotlib_converters()

# %%
text2 = ' '.join(reviews for reviews in udemy['course_title'])
wordcloud = WordCloud(stopwords=stopwords, background_color='black').generate(text2)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

wordcloud.to_file('./Dataset_PI03_Data_Analyst/img_udemy.png')

# %%
def transform_format(val):
    if val == 0:
        return 255
    elif val == 1:
        return 255
    elif val == 2:
        return 255
    else:
        return val
    
tras_course = np.ndarray((coursera_mask.shape[0], coursera_mask.shape[1]), np.int32)

for i in range(len(coursera_mask)):
    tras_course[i] = list(map(transform_format, coursera_mask[i]))

# %%
tras_course = np.ndarray((coursera_mask.shape[0], coursera_mask.shape[1]), np.int32)

for i in range(len(coursera_mask)):
    tras_course[i] = list(map(transform_format, coursera_mask[i]))
